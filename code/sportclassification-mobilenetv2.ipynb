# %%
import tensorflow as tf
import os
import PIL
import matplotlib.pyplot as plt
import numpy as np
import pathlib
import seaborn as sns
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Data

# %%
data_dir = '/kaggle/input/sports-classification'
print(os.listdir(data_dir))
# Out:
# ['EfficientNetB0-100-(224 X 224)- 98.40.h5', 'sports.csv', 'valid', 'test', 'train']

# %%
data_training = {}
data_Val = {}
data_test = {}

# %%
print ("** Sport Classification Dataset **")

for folders in os.listdir(data_dir):
    
    if folders != "EfficientNetB0-100-(224 X 224)- 98.40.h5":
        if folders != "sports.csv":

            folders_path = os.path.join(data_dir,folders)

            number_of_samples = 0

            print('**',folders,'**')

            for diseases in os.listdir(folders_path):

                diseases_path = os.path.join(folders_path,diseases)


                samples = len(os.listdir(diseases_path))

                print(diseases , ":", samples)


                number_of_samples = number_of_samples + samples

                if folders == "valid":
                  data_Val[diseases] = samples
                elif folders == "test":
                  data_test[diseases] = samples  
                else:
                  data_training[diseases] = samples



            print("Number of samples for ", folders," is ",number_of_samples)
            print("=================================================")
# Out:
# ** Sport Classification Dataset **
# ** valid **
# bobsled : 5
# hurdles : 5
# snow boarding : 5
# fly fishing : 5
# luge : 5
# sidecar racing : 5
# ampute football : 5
# volleyball : 5
# billiards : 5
# giant slalom : 5
# tennis : 5
# horse racing : 5
# pole dancing : 5
# figure skating women : 5
# rollerblade racing : 5
# fencing : 5
# olympic wrestling : 5
# golf : 5
# ultimate : 5
# harness racing : 5
# football : 5
# frisbee : 5
# bungee jumping : 5
# shot put : 5
# ice climbing : 5
# figure skating men : 5
# rowing : 5
# bike polo : 5
# swimming : 5
# judo : 5
# axe throwing : 5
# archery : 5
# baseball : 5
# wheelchair basketball : 5
# log rolling : 5
# lacrosse : 5
# rock climbing : 5
# horse jumping : 5
# hydroplane racing : 5
# formula 1 racing : 5
# curling : 5
# jousting : 5
# javelin : 5
# water cycling : 5
# speed skating : 5
# barell racing : 5
# bull riding : 5
# horseshoe pitching : 5
# croquet : 5
# chuckwagon racing : 5
# hammer throw : 5
# rugby : 5
# pole climbing : 5
# nascar racing : 5
# snowmobile racing : 5
# boxing : 5
# mushing : 5
# track bicycle : 5
# canoe slamon : 5
# disc golf : 5
# bmx : 5
# air hockey : 5
# rings : 5
# trapeze : 5
# motorcycle racing : 5
# tug of war : 5
# ski jumping : 5
# field hockey : 5
# gaga : 5
# polo : 5
# ice yachting : 5
# jai alai : 5
# wheelchair racing : 5
# bowling : 5
# weightlifting : 5
# wingsuit flying : 5
# surfing : 5
# pole vault : 5
# water polo : 5
# basketball : 5
# skydiving : 5
# uneven bars : 5
# pommel horse : 5
# cricket : 5
# sky surfing : 5
# steer wrestling : 5
# hang gliding : 5
# parallel bar : 5
# shuffleboard : 5
# cheerleading : 5
# baton twirling : 5
# balance beam : 5
# hockey : 5
# high jump : 5
# table tennis : 5
# figure skating pairs : 5
# sailboat racing : 5
# sumo wrestling : 5
# arm wrestling : 5
# roller derby : 5
# Number of samples for  valid  is  500
# =================================================
# ** test **
# bobsled : 5
# hurdles : 5
# snow boarding : 5
# fly fishing : 5
# luge : 5
# sidecar racing : 5
# ampute football : 5
# volleyball : 5
# billiards : 5
# giant slalom : 5
# tennis : 5
# horse racing : 5
# pole dancing : 5
# figure skating women : 5
# rollerblade racing : 5
# fencing : 5
# olympic wrestling : 5
# golf : 5
# ultimate : 5
# harness racing : 5
# football : 5
# frisbee : 5
# bungee jumping : 5
# shot put : 5
# ice climbing : 5
# figure skating men : 5
# rowing : 5
# bike polo : 5
# swimming : 5
# judo : 5
# axe throwing : 5
# archery : 5
# baseball : 5
# wheelchair basketball : 5
# log rolling : 5
# lacrosse : 5
# rock climbing : 5
# horse jumping : 5
# hydroplane racing : 5
# formula 1 racing : 5
# curling : 5
# jousting : 5
# javelin : 5
# water cycling : 5
# speed skating : 5
# barell racing : 5
# bull riding : 5
# horseshoe pitching : 5
# croquet : 5
# chuckwagon racing : 5
# hammer throw : 5
# rugby : 5
# pole climbing : 5
# nascar racing : 5
# snowmobile racing : 5
# boxing : 5
# mushing : 5
# track bicycle : 5
# canoe slamon : 5
# disc golf : 5
# bmx : 5
# air hockey : 5
# rings : 5
# trapeze : 5
# motorcycle racing : 5
# tug of war : 5
# ski jumping : 5
# field hockey : 5
# gaga : 5
# polo : 5
# ice yachting : 5
# jai alai : 5
# wheelchair racing : 5
# bowling : 5
# weightlifting : 5
# wingsuit flying : 5
# surfing : 5
# pole vault : 5
# water polo : 5
# basketball : 5
# skydiving : 5
# uneven bars : 5
# pommel horse : 5
# cricket : 5
# sky surfing : 5
# steer wrestling : 5
# hang gliding : 5
# parallel bar : 5
# shuffleboard : 5
# cheerleading : 5
# baton twirling : 5
# balance beam : 5
# hockey : 5
# high jump : 5
# table tennis : 5
# figure skating pairs : 5
# sailboat racing : 5
# sumo wrestling : 5
# arm wrestling : 5
# roller derby : 5
# Number of samples for  test  is  500
# =================================================
# ** train **
# bobsled : 138
# hurdles : 136
# snow boarding : 117
# fly fishing : 134
# luge : 127
# sidecar racing : 133
# ampute football : 112
# volleyball : 142
# billiards : 145
# giant slalom : 150
# tennis : 131
# horse racing : 139
# pole dancing : 112
# figure skating women : 157
# rollerblade racing : 159
# fencing : 135
# olympic wrestling : 167
# golf : 157
# ultimate : 97
# harness racing : 147
# football : 191
# frisbee : 131
# bungee jumping : 125
# shot put : 149
# ice climbing : 130
# figure skating men : 128
# rowing : 143
# bike polo : 110
# swimming : 157
# judo : 150
# axe throwing : 113
# archery : 132
# baseball : 174
# wheelchair basketball : 106
# log rolling : 128
# lacrosse : 151
# rock climbing : 141
# horse jumping : 134
# hydroplane racing : 108
# formula 1 racing : 190
# curling : 141
# jousting : 118
# javelin : 136
# water cycling : 103
# speed skating : 136
# barell racing : 123
# bull riding : 149
# horseshoe pitching : 102
# croquet : 134
# chuckwagon racing : 120
# hammer throw : 122
# rugby : 166
# pole climbing : 118
# nascar racing : 189
# snowmobile racing : 147
# boxing : 116
# mushing : 111
# track bicycle : 135
# canoe slamon : 164
# disc golf : 123
# bmx : 140
# air hockey : 112
# rings : 157
# trapeze : 125
# motorcycle racing : 132
# tug of war : 128
# ski jumping : 130
# field hockey : 157
# gaga : 118
# polo : 157
# ice yachting : 112
# jai alai : 132
# wheelchair racing : 119
# bowling : 120
# weightlifting : 134
# wingsuit flying : 98
# surfing : 142
# pole vault : 138
# water polo : 130
# basketball : 169
# skydiving : 148
# uneven bars : 156
# pommel horse : 120
# cricket : 129
# sky surfing : 59
# steer wrestling : 122
# hang gliding : 121
# parallel bar : 131
# shuffleboard : 130
# cheerleading : 131
# baton twirling : 108
# balance beam : 147
# hockey : 172
# high jump : 159
# table tennis : 141
# figure skating pairs : 151
# sailboat racing : 144
# sumo wrestling : 133
# arm wrestling : 99
# roller derby : 163
# Number of samples for  train  is  13493
# =================================================

# %%
data_training_array = np.array(list(data_training.values()))
plt.figure(figsize=(30, 18))
plt.bar(data_training.keys(), data_training_array)
plt.xticks(rotation=90)
plt.xlabel("Distribution", fontsize=30)
plt.ylabel("Number of samples", fontsize=30)
plt.title("Trining Data", fontsize=30)
plt.show()

# %% [markdown]
# # MobileNets-v3

# %%
train_dataset = tf.keras.utils.image_dataset_from_directory('/kaggle/input/sports-classification/train',
                                                            shuffle=True,
                                                            batch_size=32,
                                                            label_mode='categorical',
                                                            image_size=(160, 160))
# Out:
# Found 13492 files belonging to 100 classes.

# %%
validation_dataset = tf.keras.utils.image_dataset_from_directory('/kaggle/input/sports-classification/valid',
                                                            shuffle=True,
                                                            batch_size=32,
                                                            label_mode='categorical',
                                                            image_size=(160, 160))
# Out:
# Found 500 files belonging to 100 classes.

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal'),
  tf.keras.layers.RandomZoom(.5, .2),
  tf.keras.layers.RandomRotation(0.2),
])

# %%
preprocess_input = tf.keras.applications.mobilenet_v2.preprocess_input

# %%
base_model = tf.keras.applications.MobileNetV2(input_shape=(160,160,3),
                                               include_top=False,
                                               weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_160_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step

# %%
base_model.trainable = False

# %%
inputs = tf.keras.Input(shape=(160, 160, 3))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x, training=False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = tf.keras.layers.Dense(100, activation='softmax')(x)
model = tf.keras.Model(inputs, outputs)

# %%
model.compile(loss=tf.keras.losses.categorical_crossentropy,
              optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001),
              metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 160, 160, 3)]     0
#
#  sequential (Sequential)     (None, 160, 160, 3)       0
#
#  tf.math.truediv (TFOpLambda  (None, 160, 160, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 160, 160, 3)      0
#  a)
#
#  mobilenetv2_1.00_160 (Funct  (None, 5, 5, 1280)       2257984
#  ional)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 100)               128100
#
# =================================================================
# Total params: 2,386,084
# Trainable params: 128,100
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
history = model.fit(train_dataset,
                    epochs=20,
                    validation_data=validation_dataset,
                    callbacks=tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3))
# Out:
# Epoch 1/20
# 422/422 [==============================] - 72s 141ms/step - loss: 4.4745 - accuracy: 0.0574 - val_loss: 3.4926 - val_accuracy: 0.2000
# Epoch 2/20
# 422/422 [==============================] - 19s 44ms/step - loss: 3.3268 - accuracy: 0.2212 - val_loss: 2.6017 - val_accuracy: 0.4100
# Epoch 3/20
# 422/422 [==============================] - 18s 42ms/step - loss: 2.6864 - accuracy: 0.3523 - val_loss: 2.0822 - val_accuracy: 0.5520
# Epoch 4/20
# 422/422 [==============================] - 18s 41ms/step - loss: 2.3054 - accuracy: 0.4231 - val_loss: 1.7572 - val_accuracy: 0.6240
# Epoch 5/20
# 422/422 [==============================] - 18s 43ms/step - loss: 2.0838 - accuracy: 0.4741 - val_loss: 1.5390 - val_accuracy: 0.6620
# Epoch 6/20
# 422/422 [==============================] - 18s 42ms/step - loss: 1.8919 - accuracy: 0.5208 - val_loss: 1.3776 - val_accuracy: 0.6880
# Epoch 7/20
# 422/422 [==============================] - 19s 44ms/step - loss: 1.7594 - accuracy: 0.5477 - val_loss: 1.2586 - val_accuracy: 0.7200
# Epoch 8/20
# 422/422 [==============================] - 19s 45ms/step - loss: 1.6727 - accuracy: 0.5665 - val_loss: 1.1604 - val_accuracy: 0.7320
# Epoch 9/20
# 422/422 [==============================] - 18s 41ms/step - loss: 1.5925 - accuracy: 0.5821 - val_loss: 1.0882 - val_accuracy: 0.7440
# Epoch 10/20
# 422/422 [==============================] - 19s 44ms/step - loss: 1.5118 - accuracy: 0.5999 - val_loss: 1.0255 - val_accuracy: 0.7620
# Epoch 11/20
# 422/422 [==============================] - 18s 41ms/step - loss: 1.4595 - accuracy: 0.6171 - val_loss: 0.9816 - val_accuracy: 0.7700
# Epoch 12/20
# 422/422 [==============================] - 19s 44ms/step - loss: 1.4225 - accuracy: 0.6235 - val_loss: 0.9407 - val_accuracy: 0.7780
# Epoch 13/20
# 422/422 [==============================] - 18s 43ms/step - loss: 1.3659 - accuracy: 0.6363 - val_loss: 0.9008 - val_accuracy: 0.7820
# Epoch 14/20
# 422/422 [==============================] - 18s 42ms/step - loss: 1.3198 - accuracy: 0.6477 - val_loss: 0.8762 - val_accuracy: 0.7800
# Epoch 15/20
# 422/422 [==============================] - 19s 46ms/step - loss: 1.2896 - accuracy: 0.6527 - val_loss: 0.8376 - val_accuracy: 0.7920
# Epoch 16/20
# 422/422 [==============================] - 18s 43ms/step - loss: 1.2567 - accuracy: 0.6571 - val_loss: 0.8139 - val_accuracy: 0.7860
# Epoch 17/20
# 422/422 [==============================] - 19s 44ms/step - loss: 1.2302 - accuracy: 0.6634 - val_loss: 0.7954 - val_accuracy: 0.7960
# Epoch 18/20
# 422/422 [==============================] - 19s 44ms/step - loss: 1.2117 - accuracy: 0.6710 - val_loss: 0.7697 - val_accuracy: 0.8140
# Epoch 19/20
# 422/422 [==============================] - 18s 43ms/step - loss: 1.1835 - accuracy: 0.6723 - val_loss: 0.7566 - val_accuracy: 0.8020
# Epoch 20/20
# 422/422 [==============================] - 19s 44ms/step - loss: 1.1624 - accuracy: 0.6828 - val_loss: 0.7361 - val_accuracy: 0.8180

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(20)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.save("/kaggle/working/MobileNetv2_TransferLearning_SportsClassification.h5")

# %%
len(model.trainable_variables)
# Out:
# 2

# %%
base_model.trainable = True

print("Number of layers in the base model: ", len(base_model.layers))

fine_tune_at = 100
# Out:
# Number of layers in the base model:  154

# %%
for layer in base_model.layers[:fine_tune_at]:
  layer.trainable = False

# %%
len(model.trainable_variables)
# Out:
# 56

# %%
model.compile(loss=tf.keras.losses.categorical_crossentropy,
              optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001/10),
              metrics = ['accuracy'])

# %%
fine_tune_epochs = 50
total_epochs =  20 + fine_tune_epochs

history_fine = model.fit(train_dataset,
                         epochs=total_epochs,
                         initial_epoch=history.epoch[-1],
                         validation_data=validation_dataset,
                         callbacks=tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3))
# Out:
# Epoch 20/70
# 422/422 [==============================] - 35s 51ms/step - loss: 1.0585 - accuracy: 0.7002 - val_loss: 0.6469 - val_accuracy: 0.8180
# Epoch 21/70
# 422/422 [==============================] - 21s 49ms/step - loss: 0.9848 - accuracy: 0.7183 - val_loss: 0.5946 - val_accuracy: 0.8340
# Epoch 22/70
# 422/422 [==============================] - 20s 47ms/step - loss: 0.9260 - accuracy: 0.7314 - val_loss: 0.5805 - val_accuracy: 0.8360
# Epoch 23/70
# 422/422 [==============================] - 21s 49ms/step - loss: 0.8729 - accuracy: 0.7427 - val_loss: 0.5410 - val_accuracy: 0.8480
# Epoch 24/70
# 422/422 [==============================] - 20s 46ms/step - loss: 0.8580 - accuracy: 0.7522 - val_loss: 0.5404 - val_accuracy: 0.8540
# Epoch 25/70
# 422/422 [==============================] - 21s 49ms/step - loss: 0.8210 - accuracy: 0.7573 - val_loss: 0.5073 - val_accuracy: 0.8500
# Epoch 26/70
# 422/422 [==============================] - 21s 48ms/step - loss: 0.7843 - accuracy: 0.7711 - val_loss: 0.5119 - val_accuracy: 0.8520
# Epoch 27/70
# 422/422 [==============================] - 20s 46ms/step - loss: 0.7462 - accuracy: 0.7796 - val_loss: 0.4945 - val_accuracy: 0.8640
# Epoch 28/70
# 422/422 [==============================] - 20s 47ms/step - loss: 0.7290 - accuracy: 0.7819 - val_loss: 0.4801 - val_accuracy: 0.8680
# Epoch 29/70
# 422/422 [==============================] - 21s 48ms/step - loss: 0.7038 - accuracy: 0.7893 - val_loss: 0.4575 - val_accuracy: 0.8680
# Epoch 30/70
# 422/422 [==============================] - 19s 45ms/step - loss: 0.6945 - accuracy: 0.7973 - val_loss: 0.4557 - val_accuracy: 0.8680
# Epoch 31/70
# 422/422 [==============================] - 20s 47ms/step - loss: 0.6778 - accuracy: 0.7985 - val_loss: 0.4567 - val_accuracy: 0.8620
# Epoch 32/70
# 422/422 [==============================] - 21s 48ms/step - loss: 0.6433 - accuracy: 0.8074 - val_loss: 0.4340 - val_accuracy: 0.8700
# Epoch 33/70
# 422/422 [==============================] - 20s 47ms/step - loss: 0.6286 - accuracy: 0.8087 - val_loss: 0.4206 - val_accuracy: 0.8720
# Epoch 34/70
# 422/422 [==============================] - 20s 48ms/step - loss: 0.6345 - accuracy: 0.8067 - val_loss: 0.4319 - val_accuracy: 0.8780
# Epoch 35/70
# 422/422 [==============================] - 19s 45ms/step - loss: 0.5858 - accuracy: 0.8229 - val_loss: 0.4089 - val_accuracy: 0.8820
# Epoch 36/70
# 422/422 [==============================] - 21s 48ms/step - loss: 0.5775 - accuracy: 0.8252 - val_loss: 0.4107 - val_accuracy: 0.8800
# Epoch 37/70
# 422/422 [==============================] - 20s 47ms/step - loss: 0.5468 - accuracy: 0.8348 - val_loss: 0.4205 - val_accuracy: 0.8840
# Epoch 38/70
# 422/422 [==============================] - 19s 45ms/step - loss: 0.5402 - accuracy: 0.8345 - val_loss: 0.4224 - val_accuracy: 0.8720

# %%
acc += history_fine.history['accuracy']
val_acc += history_fine.history['val_accuracy']

loss += history_fine.history['loss']
val_loss += history_fine.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.ylim([0.7, 1])
plt.plot([20-1,20-1],
          plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.ylim([0, 2.0])
plt.plot([20-1,20-1],
         plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
model.save("/kaggle/working/MobileNetv2_FineTuning_SportsClassification.h5")
